# %% [markdown]
# # 分类器实现
#
# - 准备工作：载入需要的库

# %%
import pickle
from pandas.core.frame import DataFrame

import sqlite3
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

import numpy as np
import pandas as pd

# %% [markdown]
# - 准备工作：定义在训练中用到的且将要复用的函数

# %%
def split_spaces(data): ## 输入未处理的数据，第二列为文本，返回分割好第二列的列表。
    data_list = []
    for line in data:
        data_list.append(list(line))
        
    for item in data_list:
        item[1] = ' '.join(list(item[1]))
    return data_list

def desymbol(data):
    import re
    data_desymbol = []
    for line in data:
        data_desymbol.append(list(line))
    for row in data_desymbol:
        row[1] = ' '.join(list(re.sub("[\s+\.\!\/_,$%^*)(+\"\']+|[+——！，。？：、~@#￥%……&*（）“”]", "",row[1])))
    return data_desymbol

def add_start_end(data):
    data_with_se = []
    for line in data:
        data_with_se.append(list(line))
    for row in data_with_se:
        row[1] = "<start> "+row[1]+" <end>"
    return data_with_se

def countV(x_test):
    xtest_cv = cv.transform(x_test)
    return xtest_cv

def tfIdfV(x_test):
    x_test_tfidf = tv.transform(x_test)
    
    return x_test_tfidf

# %% [markdown]
# ## Ⅰ 数据读入与预处理

# %%
def load_from_db():
    conn = sqlite3.connect("../data/database/texts.db")
    print ('Opened database successfully')
    c = conn.cursor()

    ci_data=[]
    cursor = c.execute("SELECT * from ci order by id desc limit 10")
    for row in cursor:
        ci_data.append(row)

    poet_data = []
    cursor=c.execute("SELECT * FROM poet order by id desc limit 10")
    for row in cursor:
        poet_data.append(row)

    classical_data = []
    cursor=c.execute("SELECT * FROM classical order by id desc limit 10")
    for row in cursor:
        classical_data.append(row)

    journal_data = []
    cursor=c.execute("SELECT * FROM journal order by id desc limit 10")
    for row in cursor:
        journal_data.append(row)
    
    news_data = []
    cursor=c.execute("SELECT * FROM news order by id asc limit 10")
    for row in cursor:
        news_data.append(row)

    print("所有类型数据读取成功，各10条。")
    data = ci_data + poet_data + classical_data + journal_data + news_data
    
    return add_start_end(desymbol(split_spaces(data)))

def load_from_file(addr):
    with open(addr,mode='r',encoding='UTF-8') as file:
        content = ''
        for line in file:
            content += str(line)
        file.close()
    print("通过文件读入的内容为：\n"+content)
    data = ['1',content,'unknown']
    return data

def load_from_input(text):
    data = ['1',text,'unknown']
    return data

# %% [markdown]
# ## Ⅱ 模型文件载入

# %%
file = open("../model/NB-CV.pickle", "rb")
model_NBCV = pickle.load(file)
file.close()

file = open("../model/NB-TFIDF.pickle", "rb")
model_NBTFIDF = pickle.load(file)
file.close()

file = open("../model/LR-CV.pickle", "rb")
model_LRCV = pickle.load(file)
file.close()

file = open("../model/LR-TFIDF.pickle", "rb")
model_LRTFIDF = pickle.load(file)
file.close()

file = open("../model/CV.pkl", "rb")
cv = pickle.load(file)
file.close()

file = open("../model/tv.pkl", "rb")
tv = pickle.load(file)
file.close()

# %% [markdown]
# ## Ⅲ 模型预测

# %%
def NBCV(textlist):
    s = model_NBCV.predict(countV(textlist))
    return s

def NBTFIDF(textlist):
    s = model_NBTFIDF.predict(tfIdfV(textlist))
    return s

def LRCV(textlist):
    s = model_LRCV.predict(countV(textlist))
    return s

def LRTFIDF(textlist):
    s = model_LRTFIDF.predict(tfIdfV(textlist))
    return s

# %% [markdown]
# ## Ⅳ 实操与结果输出

# %%
def get_text(data):
    textlist = []
    if(len(np.array(data).shape) > 1):
        for row in data:
            textlist.append(row[1])
    else: textlist.append(data[1])
    return textlist

# %% [markdown]
# 数据库读入测试：

# %%
textlist = get_text(load_from_db())
c = {"text":textlist,"type_NBCV":list(NBCV(textlist)),"type_NBCVTFIDF":list(NBTFIDF(textlist)),"type_LRCV":list(LRCV(textlist)),"type_LRTFIDF":list(LRTFIDF(textlist))}
df = pd.DataFrame(c)
display(df)
# Out:
# Opened database successfully
# 所有类型数据读取成功，各2000条。
#                                                  text  type_NBCV  \
# 0                         <start> 乍 卷 珠 帘 新 燕 入 <end>         ci
# 1                         <start> 楼 台 里 春 风 淡 荡 <end>         ci
# 2                     <start> 剪 新 幡 儿 斜 插 真 珠 髻 <end>         ci
# 3   <start> 露 着 桂 枝 晓 霜 护 菊 篱 秋 无 尘 玉 宇 南 极 一 点 瑞 ...         ci
# 4   <start> 十 日 後 重 阳 甘 菊 阶 前 满 意 黄 生 日 无 钱 留 贺 客 ...         ci
# 5   <start> 龙 角 辉 春 蛾 春 惊 晓 梦 阑 金 翠 屏 开 异 芬 薰 室 风 ...         ci
# 6   <start> 薰 梅 染 柳 借 得 东 君 手 柳 色 梅 香 到 樽 前 摅 写 才 ...         ci
# 7   <start> 雪 坞 霜 林 一 夜 报 春 归 消 息 看 是 处 春 回 柳 眼 粉 ...         ci
# 8   <start> 春 玉 苍 山 屏 星 暖 佳 辰 难 得 看 柳 眼 梅 金 全 似 海 ...         ci
# 9   <start> 金 关 五 云 里 玉 座 太 微 间 凌 虚 新 就 燕 间 宣 唤 侍 ...         ci
# 10  <start> 圣 祖 发 神 谋 灵 符 叶 帝 求 一 人 光 锡 命 万 国 荷 时 ...       poet
# 11  <start> 书 劒 催 人 不 暂 闲 洛 阳 羁 旅 复 秦 关 容 颜 岁 岁 愁 ...       poet
# 12  <start> 刻 木 牵 丝 作 老 翁 鸡 皮 鹤 发 与 真 同 须 臾 弄 罢 寂 ...       poet
# 13  <start> 莫 向 嵩 山 去 神 仙 多 误 人 不 如 朝 魏 阙 天 子 重 贤 ...       poet
# 14  <start> 征 夫 走 马 发 渔 阳 少 妇 含 娇 开 洞 房 千 日 废 台 还 ...         ci
# 15  <start> 东 吴 有 灵 草 生 彼 剡 谿 傍 既 乱 莓 苔 色 仍 连 菡 萏 ...       poet
# 16  <start> 百 舌 闻 他 郡 间 关 媚 物 华 敛 形 藏 一 叶 分 响 出 千 ...       poet
# 17  <start> 宋 玉 东 家 女 常 怀 物 外 多 自 从 图 渤 海 谁 为 觅 湘 ...         ci
# 18  <start> 画 扇 出 秦 楼 谁 家 赠 列 侯 小 含 吴 剡 县 轻 带 楚 扬 ...         ci
# 19  <start> 云 端 有 灵 匹 掩 映 拂 妆 台 夜 久 应 摇 珮 天 高 响 不 ...         ci
# 20  <start> 徐 守 仁 义 社 稷 邱 墟 鲁 尊 儒 墨 宗 庙 泯 灭 非 达 奥 ...  classical
# 21  <start> 经 曰 古 者 邻 国 烽 烟 相 望 鸡 犬 相 闻 而 足 迹 不 接 ...  classical
# 22  <start> 以 兵 从 之 其 君 可 虏 其 国 可 隳 其 城 可 拔 其 众 可 ...  classical
# 23  <start> 经 曰 古 之 善 用 兵 者 必 重 天 下 之 权 而 研 诸 侯 之 ...  classical
# 24  <start> 经 曰 太 古 之 初 有 [ 木 百 ] 皇 氏 至 於 容 成 氏 不 ...  classical
# 25  <start> 经 曰 贤 人 之 生 於 世 无 籍 地 无 贵 宗 无 奇 状 无 智 ...  classical
# 26  <start> 夫 有 容 身 之 地 智 者 不 言 弱 ； 有 市 井 之 利 ； 智 ...  classical
# 27  <start> 乘 天 之 时 者 春 植 谷 秋 植 麦 夏 长 成 冬 备 藏 因 地 ...  classical
# 28  <start> 经 曰 国 之 所 以 富 强 者 审 权 以 操 柄 审 数 以 御 人 ...  classical
# 29  <start> 周 建 一 千 八 百 诸 侯 其 并 为 六 国 六 国 连 兵 结 难 ...  classical
# 30  <start> 2 0 0 3 年 卢 作 孚 先 生 被 重 庆 市 民 和 专 家 分 ...     modern
# 31  <start> 今 人 则 说 : 当 代 人 与 其 看 成 功 人 士 的 训 导 不 ...     modern
# 32  <start> 这 也 正 是 他 的 独 特 价 值 所 在 卢 作 孚 离 世 后 黄 ...     modern
# 33  <start> 美 国 杂 志 《 亚 洲 与 美 洲 》 刊 登 的 一 篇 文 章 一 ...     modern
# 34  <start> 卢 作 孚 留 给 后 人 的 不 仅 是 他 的 事 业 更 是 他 的 ...  classical
# 35  <start> 卢 作 孚 和 晏 阳 初 梁 漱 溟 并 称 中 国 乡 村 建 设 三 ...     modern
# 36  <start> 今 天 的 研 究 者 更 对 卢 作 孚 的 北 碚 乡 村 建 设 实 ...     modern
# 37  <start> 陶 行 知 也 赞 扬 说 北 碚 的 建 设 可 谓 将 来 如 何 建 ...     modern
# 38  <start> 1 9 4 4 年 美 国 杂 志 上 刊 登 的 文 章 则 称 北 碚 ...     modern
# 39  <start> 卢 作 孚 创 造 的 第 三 个 奇 迹 是 他 主 持 推 动 了 以 ...     modern
# 40  <start> 中 广 网 唐 山 ６ 月 １ ２ 日 消 息 记 者 汤 一 亮 庄 胜 ...     modern
# 41  <start> 天 津 卫 视 求 职 节 目 《 非 你 莫 属 》 晕 倒 门 事 件 ...     modern
# 42  <start> 临 沂 山 东 ２ ０ １ ２ 年 ６ 月 ４ 日 夫 妻 麦 客 忙 麦 ...     modern
# 43  <start> 中 广 网 北 京 ６ 月 １ ３ 日 消 息 记 者 王 宇 据 中 国 ...     modern
# 44  <start> 环 球 网 记 者 李 亮 报 道 正 在 意 大 利 度 蜜 月 的 脸 ...     modern
# 45  <start> 本 报 记 者 张 忠 德 １ 颈 ㄍ ㄑ 对 薄 ≌ 叛 蕖 ∷ 真 糊 ...     modern
# 46  <start> 中 新 网 ６ 月 ８ 日 电 据 朝 中 社 报 道 ２ ６ ０ 多 名 ...     modern
# 47  <start> 中 新 社 北 京 ６ 月 ２ 日 电 记 者 刘 辰 瑶 国 资 委 ２ ...     modern
# 48  <start> 证 监 会 近 日 召 开 新 闻 通 气 会 就 《 关 于 加 强 与 ...     modern
# 49  <start> 中 国 台 湾 网 ６ 月 １ ５ 日 消 息 据 台 湾 《 中 国 时 ...     modern
#
#    type_NBCVTFIDF  type_LRCV type_LRTFIDF
# 0              ci       poet         poet
# 1            poet       poet         poet
# 2            poet       poet         poet
# 3              ci         ci           ci
# 4              ci         ci           ci
# 5              ci         ci           ci
# 6              ci         ci           ci
# 7              ci         ci           ci
# 8              ci         ci           ci
# 9              ci         ci           ci
# 10           poet       poet         poet
# 11           poet       poet         poet
# 12           poet       poet         poet
# 13           poet       poet         poet
# 14             ci         ci           ci
# 15           poet       poet         poet
# 16           poet       poet         poet
# 17             ci         ci         poet
# 18           poet       poet         poet
# 19             ci       poet         poet
# 20      classical  classical    classical
# 21      classical  classical    classical
# 22      classical  classical    classical
# 23      classical  classical    classical
# 24      classical  classical    classical
# 25      classical  classical    classical
# 26      classical  classical    classical
# 27      classical  classical    classical
# 28      classical  classical    classical
# 29      classical  classical    classical
# 30         modern     modern       modern
# 31         modern  classical       modern
# 32         modern     modern       modern
# 33         modern     modern       modern
# 34      classical  classical    classical
# 35      classical     modern       modern
# 36         modern     modern       modern
# 37      classical     modern       modern
# 38         modern     modern       modern
# 39         modern     modern       modern
# 40         modern     modern       modern
# 41         modern     modern       modern
# 42         modern     modern       modern
# 43         modern     modern       modern
# 44         modern     modern       modern
# 45         modern     modern       modern
# 46         modern     modern       modern
# 47         modern     modern       modern
# 48         modern     modern       modern
# 49         modern     modern       modern

# %% [markdown]
# 输入文本测试：

# %%
textlist = get_text(load_from_input("湖滨七舍群作为武汉大学湖滨七舍学子共同创建的宿舍交流群，致力于为学子提供一个便捷、良好的交流平台。同学们可以在群内进行学术交流、问题反映、发布通知等。同时，也希望同学们注意措辞，合理合法地参与公共事务。"))
c = {"text":textlist,"type_NBCV":list(NBCV(textlist)),"type_NBCVTFIDF":list(NBTFIDF(textlist)),"type_LRCV":list(LRCV(textlist)),"type_LRTFIDF":list(LRTFIDF(textlist))}
df = pd.DataFrame(c)
display(df)
# Out:
#                                                 text type_NBCV type_NBCVTFIDF  \
# 0  湖滨七舍群作为武汉大学湖滨七舍学子共同创建的宿舍交流群，致力于为学子提供一个便捷、良好的交流...      poet           poet
#
#    type_LRCV type_LRTFIDF
# 0  classical    classical

# %% [markdown]
# 尴尬，全错
