# %% [markdown]
# ## 0.导入数据集预处理、特征工程和模型训练所需的库

# %%
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import pandas,  numpy, textblob, string #xgboost,
#from keras.preprocessing import text, sequence
#from keras import layers, models, optimizers

# %% [markdown]
# ## 1.1 连接数据库

# %%
import sqlite3
conn = sqlite3.connect("../data/database/texts.db")

print ('Opened database successfully')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-76-0834addc61ef> in <module>
#       1 import sqlite3
# ----> 2 conn = sqlite3.connect("../data/database/texts.db")
#       3
#       4 print ('Opened database successfully')
#
# OperationalError: unable to open database file

# %% [markdown]
# ## 1.2将词、诗、文言文、期刊和新闻的数据加入data列表中

# %%
c = conn.cursor()

ci_data=[]
cursor = c.execute("SELECT * from ci order by id asc limit 5000")
#cursor = c.execute("SELECT * from ci order by id")
for row in cursor:
    ci_data.append(row)
#print("读取的词数据样例：")
#print(ci_data[-2:])

poet_data = []
cursor=c.execute("SELECT * FROM poet order by id asc limit 5000")
#cursor = c.execute("SELECT * from poet order by id")
for row in cursor:
    poet_data.append(row)
#print("\n读取的诗数据样例：")
#print(poet_data[-2:])

classical_data = []
cursor=c.execute("SELECT * FROM classical order by id asc limit 5000")
#cursor = c.execute("SELECT * from classical order by id")
for row in cursor:
    classical_data.append(row)
#print("\n读取的文言文数据样例：")
#print(classical_data[-2:])

journal_data = []
cursor=c.execute("SELECT * FROM journal order by id asc limit 5000")
#cursor = c.execute("SELECT * from journal order by id")
for row in cursor:
    journal_data.append(row)
#print("\n读取的期刊数据样例：")
#print(journal_data[:2])
    
news_data = []
cursor=c.execute("SELECT * FROM news order by id asc limit 5000")
#cursor=c.execute("SELECT * FROM news")
for row in cursor:
    news_data.append(row)
#print("\n读取的新闻数据样例：")
#print(news_data[:2])

print("add successfully")
# Out:
# add successfully

# %% [markdown]
# # 2.特征工程 + 模型训练

# %% [markdown]
# ## 2.0.1 Basic方案：对原文本拆分成单字

# %%
data = ci_data + poet_data + classical_data + journal_data + news_data

data_list = []
for line in data:
    data_list.append(list(line))

print(data_list[6000])
for item in data_list:
    item[1] = ' '.join(list(item[1]))
print(data_list[6000])
print(len(data_list))
# Out:
# [40001139, '独上江楼望故乡，泪襟霜笛共凄凉。 云生陇首秋虽早，月在天心夜已长。 魂梦只能随蛱蝶，烟波无计学鸳鸯。 蜀笺都有三千幅，总写离情寄孟光。 ', 'poet', 'a3e2bff9-e5a5-4f79-ad94-663be75d15f5']
# [40001139, '独 上 江 楼 望 故 乡 ， 泪 襟 霜 笛 共 凄 凉 。   云 生 陇 首 秋 虽 早 ， 月 在 天 心 夜 已 长 。   魂 梦 只 能 随 蛱 蝶 ， 烟 波 无 计 学 鸳 鸯 。   蜀 笺 都 有 三 千 幅 ， 总 写 离 情 寄 孟 光 。  ', 'poet', 'a3e2bff9-e5a5-4f79-ad94-663be75d15f5']
# 25000

# %% [markdown]
# ## 2.0.2 Pro: 清理时去掉符号（利用正则表达式）

# %%
import re

train_data_pro = []
for paragraph in train_data:
    train_data_pro.append(' '.join(list((re.sub("[\s+\.\!\/_,$%^*)(+\"\']+|[+——！，。？、~@#￥%……&*（）]", "",paragraph)))))


print("去除符号成功：\n样例：【"+train_data[6000]+"】=========>【"+train_data_pro[6000]+"】")
# Out:
# 去除符号成功：
# 样例：【独上江楼望故乡，泪襟霜笛共凄凉。 云生陇首秋虽早，月在天心夜已长。 魂梦只能随蛱蝶，烟波无计学鸳鸯。 蜀笺都有三千幅，总写离情寄孟光。 】=========>【独 上 江 楼 望 故 乡 泪 襟 霜 笛 共 凄 凉 云 生 陇 首 秋 虽 早 月 在 天 心 夜 已 长 魂 梦 只 能 随 蛱 蝶 烟 波 无 计 学 鸳 鸯 蜀 笺 都 有 三 千 幅 总 写 离 情 寄 孟 光】

# %%
x_train_pro, x_test_pro, y_train, y_test = train_test_split(train_data_pro, train_target,test_size=0.3,random_state=0)
from sklearn.feature_extraction.text import CountVectorizer
#cv = CountVectorizer(analyzer='char')
#vector_pro = cv.fit_transform(x_train_pro)
#vector_pro.todense()
vectorizer_pro = CountVectorizer(analyzer='char', max_features=5000)
vectorizer_pro.fit(x_train_pro)
print(x_train_pro[:3])
# Out:
# ['梁 启 超 一 生 无 论 在 政 治 还 是 学 术 上 都 是 流 质 嬗 变 而 好 讲 学 派 却 始 终 一 贯 从 未 动 摇 他 后 来 写 《 清 代 学 术 概 论 》 《 中 国 近 三 百 年 学 术 史 》 《 近 代 学 风 之 地 理 的 分 布 》 《 老 孔 墨 以 后 学 派 概 观 》 《 中 国 历 史 研 究 法 补 编 》 《 儒 家 哲 学 》 等 著 作 均 强 调 派 分 之 于 学 术 史 研 究 的 重 要 并 进 一 步 归 纳 为 系 统 化 的 方 法 他 在 《 中 国 历 史 研 究 法 补 编 》 讲 述 文 化 专 史 及 其 做 法 关 于 学 术 思 想 史 分 为 道 术 史 即 哲 学 史 史 学 史 自 然 科 学 史 和 社 会 科 学 史 四 部 着 重 讲 了 第 一 部 他 提 出 将 几 千 年 来 的 各 种 道 术 分 为 主 系 润 系 旁 系 三 类 所 谓 主 系 是 中 国 民 族 自 己 发 明 组 织 出 来 有 价 值 有 权 威 的 学 派 对 于 世 界 文 化 有 贡 献 的 ; 润 系 是 继 承 曾 做 主 系 的 学 派 做 整 理 解 释 的 工 作 如 汉 唐 和 清 代 ; 旁 系 则 是 外 国 思 想 输 入 融 合 然 后 演 化 成 第 二 主 系 如 佛 学 面 对 浩 如 烟 海 的 典 籍 和 纷 纭 错 乱 的 表 象 只 要 集 中 于 主 系 又 抓 住 派 分 便 可 以 提 纲 挈 领 例 如 “ 做 道 术 史 做 到 先 秦 最 要 紧 的 是 分 派 ” 派 分 的 主 张 各 人 不 同 在 梁 启 超 看 来 只 分 儒 道 墨 三 家 就 够 了 最 多 加 上 阴 阳 家 和 法 家 而 叙 述 润 系 “ 第 一 要 紧 的 事 就 要 把 各 家 的 脉 络 提 清 看 他 如 何 各 自 承 受 以 前 的 学 风 如 何 各 自 解 释 本 派 的 学 说 如 何 本 派 又 分 裂 为 几 派 如 何 此 派 又 和 彼 派 混 合 ” 研 究 外 来 旁 系 的 佛 教 也 要 用 研 究 先 秦 各 家 的 方 法 去 研 究 各 宗 派 至 于 第 二 主 系 虽 然 因 许 多 家 数 所 讨 论 的 不 过 小 问 题 不 可 多 分 派 别 还 是 要 分 成 程 朱 陆 王 二 派 其 余 各 小 派 则 可 择 要 叙 述', '素 灵 失 律 诈 风 流 强 把 芳 菲 半 载 偷 是 叶 葳 蕤 霜 照 夜 此 花 烂 熳 火 烧 秋 谢 莲 色 淡 争 堪 种 陶 菊 香 秾 亦 合 羞 谁 道 金 风 能 肃 物 因 何 厚 薄 不 相 侔', '２ ０ １ ２ 年 ７ 月 １ 日 位 于 长 沙 湘 江 大 道 与 营 盘 西 路 交 会 处 的 东 建 · 潮 宗 御 苑 全 江 景 营 销 中 心 开 放 推 出 了 １ ５ ０ － ２ １ ０ ㎡ 一 线 全 江 景 房 Ｖ Ｉ Ｐ 全 城 招 募 进 行 中 ＞ 萘 私 猓 潮 宗 御 苑 此 前 的 ３ ０ ０ 套 公 寓 小 户 型 未 正 式 开 盘 就 抢 购 一 空 此 次 推 出 的 １ ５ ０ － ２ １ ０ ㎡ 的 三 房 四 房 产 品 户 户 面 江 拥 有 ５ ． １ 米 开 间 大 客 厅 ２ ７ ０ 度 环 景 阳 台 并 引 进 ７ 大 家 居 智 能 化 系 统 ３ 弊 谟 苑 相 关 负 责 人 介 绍 项 目 占 地 面 积 １ ２ １ ６ ６ ㎡ 总 建 筑 面 积 约 １ ４ ６ ０ ０ ０ ㎡ 由 ３ 栋 限 高 １ ４ ０ 米 规 划 ４ ６ 层 和 一 栋 限 高 ９ ０ 米 规 划 ２ ８ 层 的 建 筑 群 组 成 规 划 总 户 数 ８ ０ ０ 余 户 项 目 紧 靠 五 一 广 场 黄 兴 路 步 行 街 万 达 广 场 三 大 商 圈 周 围 交 通 购 物 教 育 休 闲 娱 乐 等 配 套 资 源 完 善 还 毗 邻 地 铁 １ ２ 号 线 大 型 中 转 站']

# %%
print("去除符号后的训练结果：")
train_NBayes(x_train_pro, x_test_pro, y_train, y_test)
train_TfIdf(x_train_pro, x_test_pro, y_train, y_test)
train_nGram(x_train_pro, x_test_pro, y_train, y_test,2)
# Out:
# 去除符号后的训练结果：
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-40e2d0cd0a96> in <module>
#       1 print("去除符号后的训练结果：")
# ----> 2 train_NBayes(x_train_pro, x_test_pro, y_train, y_test)
#       3 train_TfIdf(x_train_pro, x_test_pro, y_train, y_test)
#       4 train_nGram(x_train_pro, x_test_pro, y_train, y_test,2)
#
# NameError: name 'train_NBayes' is not defined

# %% [markdown]
# ## 2.0.3 Pro+: 头尾加上`<start>` `<end>` 标记

# %%
train_data_prop = []
for paragraph in train_data_pro:
    train_data_prop.append("<start> "+paragraph+" <end>")

print(train_data_prop[6000])
# Out:
# <start> 独 上 江 楼 望 故 乡 泪 襟 霜 笛 共 凄 凉 云 生 陇 首 秋 虽 早 月 在 天 心 夜 已 长 魂 梦 只 能 随 蛱 蝶 烟 波 无 计 学 鸳 鸯 蜀 笺 都 有 三 千 幅 总 写 离 情 寄 孟 光 <end>

# %%
x_train_prop, x_test_prop, y_train, y_test = train_test_split(train_data_prop, train_target,test_size=0.4,random_state=0)
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(analyzer='char')
vector_prop = cv.fit_transform(x_train_prop)
vector_prop.todense()
vectorizer_prop = CountVectorizer(analyzer='char', max_features=5000)
vectorizer_prop.fit(x_train_prop)
print(x_train_prop[4000])
# Out:
# <start> 时 平 物 茂 岁 功 成 重 翟 排 云 到 玉 京 四 海 未 知 春 色 至 今 宵 先 入 九 重 城 <end>

# %%
print("加上标记后的训练结果：")
train_NBayes(x_train_prop, x_test_prop, y_train, y_test)
train_TfIdf(x_train_prop, x_test_prop, y_train, y_test)
train_nGram(x_train_prop, x_test_prop, y_train, y_test,2)

# %% [markdown]
# ## 2.1 建立拆分训练数据集

# %%
train_data=[]
train_target=[]
for i in range(0,len(data)):
    train_data.append(data[i][1])
    train_target.append(data[i][2])
print(train_data[:3])
print(train_target[15000:15003])
# Out:
# ['气和玉烛，睿化著鸿明。 缇管一阳生。 郊盛礼燔柴毕，旋轸凤凰城。 森罗仪卫振华缨。 载路溢欢声。 皇图大业超前古，垂象泰阶平。 岁时丰衍，九土乐升平。 睹寰海澄清。 道高尧舜垂衣治，日月并文明。 嘉禾甘露登歌荐，云物焕祥经。 兢兢惕惕持谦德，未许禅云亭。', '严夜警，铜莲漏迟迟。 清禁肃，森陛戟，羽卫俨皇闱。 角声励，钲鼓攸宜。 金管成雅奏，逐吹逶迤。 荐苍璧，郊祀神祗。 属景运纯禧。 京坻丰衍，群材乐育，诸侯述职，盛德服蛮夷。 殊祥萃，九苞丹凤来仪。 膏露降，和气洽，三秀焕灵芝。 鸿猷播，史册相辉。 张四维。 卜世永固丕基。 敷玄化，荡荡无为。 合尧舜文思。 混并寰宇，休牛归马，销金偃革，蹈咏庆昌期。', '承宝运，驯致隆平。 鸿庆被寰瀛。 时清俗阜，治定功成。 遐迩咏由庚。 严郊祀，文物声明。 会天正、星拱奏严更。 布羽仪簪缨。 宸心虔洁，明德播惟馨。 动苍冥。 神降享精诚。 燔柴半，万乘移天仗，肃銮辂旋衡。 千官云拥，群后葵倾。 玉帛旅明庭。 韶荐，金奏谐声。 集休亨。 皇泽浃黎庶，普率洽恩荣。 仰钦元后，睿圣贯三灵。 万邦宁。 景贶福千龄。']
# ['modern', 'modern', 'modern']

# %%
print(data[10000:10002])
# Out:
# [(10000002, '廿二史劄記 作者：清 趙翼撰作者：清 趙翼撰趙翼二十二史劄記為清代史學考據重要著作（與錢大昕二十二史考異、王鳴盛十七史商榷並稱清代歷史考據三大名著）。其以筆記條列方式，考據包括史記至明史等二十四史，（其時舊唐書及舊五代史尚未列入正史，故稱二十二史）計三十六卷，補遺一卷。內容主要就史書的編撰編撰過程、時間，史料來源、真偽）、體例（異同優劣）加以考據，兼論政事、制度、人物之優劣臧否。\n', 'classical', 'c_list_1.txt'), (10000003, '刘餗隋唐嘉话，旧唐书经籍志和新唐书艺文志都没有着录。南宋陈振孙直齐书录解题在小说家类里着录了隋唐嘉话一卷，刘餗撰。宋史艺文志也有隋唐嘉话一卷，列在刘餗的传记和小说之间。现存的顾氏文房小说本，据宋版重雕，书中贞字、构字等选缺笔，分上中下三卷。又有稽古堂丛刻本，与顾氏本基本相同，似出一源。还在历代小史本和唐人说荟等本，不分卷，条目较少。\n', 'classical', 'c_list_1.txt')]

# %% [markdown]
# #### 测试集和训练集的切分比例为0.3

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(train_data, train_target,test_size=0.3,random_state=0)

# %% [markdown]
# ## 2.1 计数向量作为特征

# %% [markdown]
# 计数向量是数据集的矩阵表示，其中每行代表来自语料库的文档，每列表示来自语料库的术语，并且每个单元格表示特定文档中特定术语的频率计数：

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(analyzer='char', max_features=5000)
vectorizer.fit(x_train)

xtrain_count = vectorizer.transform(x_train)
xtest_count = vectorizer.transform(x_test)

print(type(xtrain_count))
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>

# %% [markdown]
# #### 词汇表示

# %%
vectorizer.vocabulary_
# Out:
# {'梁': 2168,
#  '启': 805,
#  '超': 4168,
#  '一': 223,
#  '生': 2804,
#  ',': 9,
#  ' ': 2,
#  '无': 1957,
#  '论': 3986,
#  '在': 965,
#  '政': 1901,
#  '治': 2366,
#  '还': 4287,
#  '是': 1989,
#  '学': 1197,
#  '术': 2064,
#  '上': 229,
#  '都': 4390,
#  '流': 2406,
#  '质': 4115,
#  '变': 747,
#  '而': 3408,
#  '好': 1097,
#  '讲': 3979,
#  '派': 2405,
#  '却': 709,
#  '始': 1120,
#  '终': 3273,
#  '贯': 4122,
#  '从': 333,
#  '未': 2060,
#  '动': 635,
#  '摇': 1860,
#  '。': 163,
#  '他': 338,
#  '后': 784,
#  '来': 2086,
#  '写': 539,
#  '《': 167,
#  '清': 2476,
#  '代': 343,
#  '概': 2210,
#  '》': 168,
#  '、': 162,
#  '中': 252,
#  '国': 954,
#  '近': 4284,
#  '三': 228,
#  '百': 2876,
#  '年': 1406,
#  '史': 766,
#  '风': 4726,
#  '之': 268,
#  '地': 968,
#  '理': 2761,
#  '的': 2878,
#  '分': 587,
#  '布': 1374,
#  '老': 3403,
#  '孔': 1185,
#  '墨': 1036,
#  '以': 345,
#  '观': 3936,
#  '历': 717,
#  '研': 2970,
#  '究': 3090,
#  '法': 2375,
#  '(': 6,
#  '补': 3879,
#  '编': 3331,
#  ')': 7,
#  '儒': 495,
#  '家': 1234,
#  '哲': 871,
#  '等': 3159,
#  '著': 3724,
#  '作': 394,
#  '均': 974,
#  '强': 1476,
#  '调': 4048,
#  '于': 297,
#  '重': 4432,
#  '要': 3930,
#  '并': 1407,
#  '进': 4289,
#  '步': 2268,
#  '归': 1478,
#  '纳': 3257,
#  '为': 259,
#  '系': 3230,
#  '统': 3288,
#  '化': 664,
#  '方': 1942,
#  '述': 4303,
#  '文': 1921,
#  '专': 235,
#  '及': 739,
#  '其': 523,
#  '做': 472,
#  '关': 520,
#  '思': 1547,
#  '想': 1617,
#  '道': 4348,
#  '即': 708,
#  '自': 3529,
#  '然': 2633,
#  '科': 3061,
#  '和': 838,
#  '社': 3024,
#  '会': 365,
#  '四': 945,
#  '部': 4385,
#  '着': 2925,
#  '了': 291,
#  '第': 3151,
#  '提': 1839,
#  '出': 578,
#  '将': 1266,
#  '几': 567,
#  '千': 681,
#  '各': 777,
#  '种': 3060,
#  '主': 260,
#  '润': 2445,
#  '旁': 1945,
#  '类': 3204,
#  '所': 1683,
#  '谓': 4063,
#  '民': 2306,
#  '族': 1953,
#  '己': 1365,
#  '发': 743,
#  '明': 1977,
#  '组': 3269,
#  '织': 3272,
#  '有': 2049,
#  '价': 351,
#  '值': 464,
#  '权': 2072,
#  '威': 1134,
#  '对': 1259,
#  '世': 238,
#  '界': 2819,
#  '贡': 4108,
#  '献': 2723,
#  ';': 24,
#  '继': 3294,
#  '承': 1712,
#  '曾': 2045,
#  '整': 1919,
#  '解': 3947,
#  '释': 4430,
#  '工': 1358,
#  '如': 1098,
#  '汉': 2324,
#  '唐': 874,
#  '则': 597,
#  '外': 1054,
#  '输': 4256,
#  '入': 512,
#  '融': 3850,
#  '合': 779,
#  '演': 2539,
#  '成': 1668,
#  '二': 295,
#  '佛': 393,
#  '面': 4669,
#  '浩': 2423,
#  '烟': 2612,
#  '海': 2428,
#  '典': 525,
#  '籍': 3202,
#  '纷': 3260,
#  '纭': 3253,
#  '错': 4502,
#  '乱': 288,
#  '表': 3880,
#  '象': 4096,
#  '只': 758,
#  '集': 4624,
#  '又': 737,
#  '抓': 1718,
#  '住': 385,
#  '便': 423,
#  '可': 763,
#  '纲': 3256,
#  '挈': 1778,
#  '领': 4709,
#  '例': 408,
#  '“': 98,
#  '到': 606,
#  '先': 503,
#  '秦': 3066,
#  '最': 2047,
#  '紧': 3234,
#  '”': 99,
#  '张': 1466,
#  '人': 322,
#  '不': 231,
#  '同': 782,
#  '看': 2914,
#  '就': 1279,
#  '够': 1058,
#  '多': 1056,
#  '加': 632,
#  '阴': 4572,
#  '阳': 4571,
#  '叙': 748,
#  '事': 294,
#  '把': 1715,
#  '脉': 3490,
#  '络': 3285,
#  '何': 389,
#  '受': 746,
#  '前': 616,
#  '本': 2062,
#  '说': 4033,
#  '裂': 3903,
#  '此': 2267,
#  '彼': 1494,
#  '混': 2472,
#  '教': 1909,
#  '也': 282,
#  '用': 2805,
#  '去': 734,
#  '宗': 1214,
#  '至': 3532,
#  '虽': 3807,
#  '因': 947,
#  '许': 3984,
#  '数': 1917,
#  '讨': 3972,
#  '过': 4280,
#  '小': 1269,
#  '问': 4532,
#  '题': 4720,
#  '别': 604,
#  '程': 3074,
#  '朱': 2065,
#  '陆': 4581,
#  '王': 2738,
#  '余': 391,
#  '择': 1764,
#  '\n': 1,
#  '素': 3232,
#  '灵': 2577,
#  '失': 1068,
#  '律': 1503,
#  '诈': 3995,
#  '，': 4949,
#  '芳': 3597,
#  '菲': 3698,
#  '半': 685,
#  '载': 4241,
#  '偷': 476,
#  '叶': 769,
#  '霜': 4653,
#  '照': 2640,
#  '夜': 1057,
#  '花': 3596,
#  '烂': 2606,
#  '熳': 2652,
#  '火': 2573,
#  '烧': 2615,
#  '秋': 3059,
#  '谢': 4075,
#  '莲': 3676,
#  '色': 3566,
#  '淡': 2466,
#  '争': 293,
#  '堪': 1019,
#  '陶': 4599,
#  '菊': 3687,
#  '香': 4770,
#  '亦': 312,
#  '羞': 3379,
#  '谁': 4046,
#  '金': 4435,
#  '能': 3487,
#  '肃': 3435,
#  '物': 2686,
#  '厚': 724,
#  '薄': 3773,
#  '相': 2908,
#  '２': 4955,
#  '０': 4953,
#  '１': 4954,
#  '７': 4960,
#  '月': 2048,
#  '日': 1959,
#  '位': 383,
#  '长': 4527,
#  '沙': 2351,
#  '湘': 2502,
#  '江': 2330,
#  '大': 1061,
#  '与': 232,
#  '营': 3713,
#  '盘': 2899,
#  '西': 3929,
#  '路': 4193,
#  '交': 310,
#  '处': 1049,
#  '东': 243,
#  '建': 1449,
#  '·': 61,
#  '潮': 2555,
#  '御': 1511,
#  '苑': 3611,
#  '全': 513,
#  '景': 2013,
#  '销': 4493,
#  '心': 1520,
#  '开': 1450,
#  '放': 1900,
#  '推': 1831,
#  '５': 4958,
#  '－': 4950,
#  '线': 3266,
#  '房': 1682,
#  'ｖ': 4993,
#  'ｉ': 4980,
#  'ｐ': 4987,
#  '城': 1003,
#  '招': 1755,
#  '募': 652,
#  '行': 3870,
#  '＞': 4967,
#  '萘': 3710,
#  '私': 3055,
#  '猓': 2714,
#  '３': 4956,
#  '套': 1087,
#  '公': 515,
#  '寓': 1248,
#  '户': 1680,
#  '型': 994,
#  '正': 2266,
#  '式': 1458,
#  '抢': 1727,
#  '购': 4120,
#  '空': 3093,
#  '次': 2253,
#  '产': 313,
#  '品': 857,
#  '拥': 1760,
#  '．': 4951,
#  '米': 3203,
#  '间': 4537,
#  '客': 1224,
#  '厅': 716,
#  '度': 1434,
#  '环': 2743,
#  '台': 764,
#  '引': 1461,
#  '居': 1291,
#  '智': 2017,
#  '弊': 1456,
#  '谟': 4073,
#  '负': 4107,
#  '责': 4110,
#  '介': 331,
#  '绍': 3275,
#  '项': 4700,
#  '目': 2904,
#  '占': 696,
#  '积': 3068,
#  '６': 4959,
#  '总': 1555,
#  '筑': 3163,
#  '约': 3248,
#  '４': 4957,
#  '由': 2810,
#  '栋': 2136,
#  '限': 4587,
#  '高': 4815,
#  '规': 3937,
#  '划': 593,
#  '层': 1290,
#  '９': 4962,
#  '８': 4961,
#  '群': 3381,
#  '靠': 4667,
#  '五': 302,
#  '广': 1413,
#  '场': 970,
#  '黄': 4902,
#  '兴': 521,
#  '街': 3873,
#  '万': 226,
#  '达': 4275,
#  '商': 885,
#  '圈': 959,
#  '周': 829,
#  '围': 952,
#  '通': 4325,
#  '育': 3457,
#  '休': 361,
#  '闲': 4535,
#  '娱': 1147,
#  '乐': 273,
#  '配': 4400,
#  '资': 4138,
#  '源': 2511,
#  '完': 1211,
#  '善': 900,
#  '毗': 2297,
#  '邻': 4375,
#  '铁': 4474,
#  '号': 770,
#  '转': 4231,
#  '站': 3118,
#  '诰': 4030,
#  '子': 1184,
#  '：': 4963,
#  '彝': 1481,
#  '酒': 4401,
#  '越': 4169,
#  '庶': 1438,
#  '饮': 4749,
#  '惟': 1606,
#  '祀': 3025,
#  '德': 1518,
#  '醉': 4418,
#  '曰': 2037,
#  '我': 1669,
#  '迪': 4300,
#  '土': 963,
#  '爱': 2664,
#  '厥': 729,
#  '臧': 3528,
#  '聪': 3432,
#  '听': 802,
#  '祖': 3030,
#  '考': 3404,
#  '遗': 4349,
#  '训': 3975,
#  '企': 355,
#  '业': 241,
#  '1': 14,
#  '2': 15,
#  '量': 4434,
#  'x': 55,
#  'i': 40,
#  '保': 436,
#  '证': 3992,
#  '存': 1188,
#  '性': 1551,
#  '假': 467,
#  '定': 1217,
#  'm': 44,
#  'e': 36,
#  '这': 4288,
#  '策': 3166,
#  '略': 2825,
#  '非': 4666,
#  '复': 1051,
#  '康': 1439,
#  '模': 2235,
#  '误': 4029,
#  '现': 2744,
#  '忽': 1535,
#  '视': 3939,
#  '样': 2144,
#  '实': 1221,
#  ':': 23,
#  '省': 2911,
#  '掉': 1820,
#  '丰': 253,
#  '富': 1245,
#  '太': 1063,
#  '活': 2402,
#  '计': 3967,
#  '应': 1424,
#  '付': 340,
#  '困': 951,
#  '难': 4619,
#  '利': 603,
#  '们': 347,
#  '求': 2322,
#  '根': 2146,
#  '支': 1894,
#  '那': 4366,
#  '么': 266,
#  '被': 3900,
#  '普': 2012,
#  '遍': 4342,
#  '压': 719,
#  '垮': 1000,
#  '真': 2915,
#  '茗': 3635,
#  '慰': 1644,
#  '铃': 4475,
#  '斋': 1922,
#  '更': 2040,
#  '伴': 376,
#  '仙': 341,
#  '卿': 713,
#  '逸': 4335,
#  '藻': 3788,
#  '晓': 2002,
#  '吟': 794,
#  '俱': 446,
#  '绝': 3286,
#  '尘': 1273,
#  '埃': 1001,
#  '飘': 4729,
#  '砌': 2967,
#  '蔌': 3755,
#  '细': 3271,
#  '梅': 2169,
#  '雨': 4633,
#  '苹': 3626,
#  '起': 4166,
#  '情': 1599,
#  '随': 4606,
#  '水': 2318,
#  '远': 4290,
#  '梦': 2173,
#  '绕': 3280,
#  '吴': 806,
#  '峰': 1333,
#  '翠': 3393,
#  '琴': 2769,
#  '书': 285,
#  '倦': 458,
#  '鹧': 4886,
#  '鸪': 4861,
#  '唤': 875,
#  '南': 693,
#  '窗': 3104,
#  '睡': 2930,
#  '密': 1243,
#  '意': 1626,
#  '寄': 1241,
#  '幽': 1411,
#  '恨': 1568,
#  '凭': 571,
#  '洗': 2396,
#  '修': 444,
#  '竹': 3128,
#  '畔': 2821,
#  '疏': 2838,
#  '帘': 1383,
#  '里': 4431,
#  '歌': 2264,
#  '馀': 4760,
#  '拂': 1737,
#  '扇': 1686,
#  '舞': 3547,
#  '罢': 3366,
#  '掀': 1818,
#  '袂': 3891,
#  '散': 1914,
#  '後': 1504,
#  '钩': 4465,
#  '天': 1062,
#  '夭': 1065,
#  '华': 686,
#  '艳': 3567,
#  '轻': 4240,
#  '雾': 4640,
#  '春': 1985,
#  '时': 1969,
#  '似': 380,
#  '朝': 2056,
#  '云': 299,
#  '乳': 289,
#  '鸡': 4856,
#  '燕': 2657,
#  '落': 3721,
#  '星': 1983,
#  '沈': 2346,
#  '头': 1069,
#  '鼓': 4918,
#  '参': 736,
#  '差': 1364,
#  '渐': 2481,
#  '辨': 4268,
#  '池': 2331,
#  '树': 2138,
#  '阁': 4549,
#  '斜': 1930,
#  '欹': 2259,
#  '绿': 3314,
#  '苔': 3613,
#  '深': 2470,
#  '径': 1498,
#  '少': 1270,
#  '屐': 1296,
#  '痕': 2855,
#  '粉': 3205,
#  '剩': 623,
#  '衾': 3888,
#  '枕': 2102,
#  '赋': 4141,
#  '遵': 4355,
#  '守': 1208,
#  '共': 519,
#  '尊': 1268,
#  '网': 3360,
#  '担': 1739,
#  '切': 588,
#  '您': 1592,
#  '直': 2907,
#  '接': 1829,
#  '或': 1671,
#  '任': 352,
#  'ｈ': 4979,
#  '嗣': 919,
#  '裢': 3911,
#  '河': 2363,
#  '频': 4716,
#  '管': 3179,
#  '笔': 3139,
#  '名': 783,
#  '留': 2822,
#  '言': 3952,
#  '力': 628,
#  'ｄ': 4975,
#  '板': 2097,
#  '内': 531,
#  '缒': 3327,
#  '见': 3935,
#  '请': 4036,
#  '向': 787,
#  '员': 823,
#  '反': 742,
#  '映': 1984,
#  '命': 834,
#  '野': 4433,
#  '虞': 3798,
#  '毋': 2290,
#  '伐': 360,
#  '桑': 2158,
#  '柘': 2122,
#  '鸣': 4858,
#  '鸠': 4855,
#  '羽': 3387,
#  '戴': 1679,
#  '胜': 3472,
#  '降': 4586,
#  '具': 524,
#  '曲': 2038,
#  '植': 2197,
#  '筐': 3162,
#  '妃': 1099,
#  '齐': 4923,
#  '戒': 1670,
#  '亲': 320,
#  '躬': 4223,
#  '禁': 3042,
#  '妇': 1102,
#  '女': 1092,
#  '使': 403,
#  '劝': 629,
#  '蚕': 3815,
#  '既': 1958,
#  '登': 2873,
#  '茧': 3637,
#  '称': 3069,
#  '丝': 244,
#  '效': 1903,
#  '功': 631,
#  '郊': 4378,
#  '庙': 1428,
#  '服': 2051,
#  '敢': 1913,
#  '奔': 1084,
#  '丧': 249,
#  '升': 682,
#  '阶': 4574,
#  '殡': 2281,
#  '坐': 978,
#  '哭': 870,
#  '尽': 1285,
#  '哀': 856,
#  '拾': 1773,
#  '踊': 4200,
#  '当': 1479,
#  '劫': 638,
#  '持': 1775,
#  '者': 3406,
#  '（': 4945,
#  '警': 3964,
#  'ｒ': 4989,
#  'ｏ': 4986,
#  'ｌ': 4983,
#  'ａ': 4972,
#  'ｎ': 4985,
#  'ｍ': 4984,
#  'ｅ': 4976,
#  'ｚ': 4997,
#  '）': 4946,
#  '府': 1430,
#  '两': 247,
#  '谈': 4053,
#  '判': 602,
#  '橙': 2244,
#  '衣': 3877,
#  '白': 2875,
#  '协': 687,
#  '执': 1699,
#  '务': 633,
#  '船': 3559,
#  '监': 2894,
#  '亚': 305,
#  '航': 3550,
#  '期': 2057,
#  '维': 3304,
#  '巡': 1356,
#  '＃': 4942,
#  '翟': 3392,
#  '碌': 2995,
#  '哪': 869,
#  '虾': 3808,
#  '希': 1378,
#  '碧': 3005,
#  '蓝': 3750,
#  '望': 2055,
#  '际': 4580,
#  '形': 1482,
#  '态': 1538,
#  '异': 1452,
#  '悠': 1589,
#  '倒': 452,
#  '荡': 3654,
#  '阵': 4573,
#  '涌': 2434,
#  '波': 2380,
#  '打': 1694,
#  '溅': 2509,
#  '朵': 2067,
#  '浪': 2424,
#  '光': 504,
#  '粼': 3219,
#  '鸥': 4859,
#  '翩': 3396,
#  '跹': 4198,
#  '飞': 4732,
#  '鱼': 4835,
#  '雀': 4620,
#  '跃': 4178,
#  '构': 2099,
#  '幅': 1398,
#  '画': 2816,
#  '卷': 711,
#  '暇': 2021,
#  '欣': 2255,
#  '赏': 4144,
#  '美': 3377,
#  '驾': 4787,
#  '驶': 4781,
#  '室': 1226,
#  '边': 4273,
#  '认': 3970,
#  '注': 2383,
#  '雷': 4638,
#  '显': 1994,
#  '示': 3021,
#  '屏': 1295,
#  '倍': 450,
#  '镜': 4523,
#  '仔': 336,
#  '觉': 3941,
#  '察': 1251,
#  '吹': 809,
#  '迟': 4293,
#  '雪': 4634,
#  '初': 600,
#  '晴': 2015,
#  '乔': 276,
#  '枝': 2106,
#  '待': 1499,
#  '早': 1963,
#  '鶑': 4853,
#  '郎': 4379,
#  '官': 1215,
#  '妓': 1107,
#  '字': 1187,
#  '英': 3624,
#  '倏': 451,
#  '陈': 4583,
#  '依': 412,
#  '稀': 3073,
#  '旧': 1961,
#  '新': 1940,
#  '岁': 1307,
#  '访': 3990,
#  '须': 4702,
#  '虚': 3797,
#  '左': 1359,
#  '迎': 4282,
#  '征': 1496,
#  '帆': 1376,
#  '挂': 1776,
#  '酣': 4404,
#  '暮': 2029,
#  '离': 3051,
#  '晚': 2007,
#  '霞': 4654,
#  '北': 665,
#  '洲': 2401,
#  '橘': 2243,
#  '洞': 2398,
#  '庭': 1436,
#  '溪': 2515,
#  '送': 4310,
#  '寺': 1260,
#  '石': 2962,
#  '惊': 1601,
#  '龙': 4934,
#  '潭': 2554,
#  '莫': 3674,
#  '羁': 3374,
#  '魂': 4827,
#  '吊': 781,
#  '魄': 4828,
#  '九': 280,
#  '疑': 2839,
#  '愁': 1623,
#  '锁': 4494,
#  '岚': 1313,
#  '賢': 4104,
#  '雖': 4631,
#  '父': 2666,
#  '兄': 500,
#  '師': 1389,
#  '勉': 647,
#  '學': 1201,
#  '；': 4964,
#  '县': 735,
#  '师': 1377,
#  '掌': 1821,
#  '邦': 4367,
#  '鄙': 4391,
#  '稍': 3075,
#  '甸': 2815,
#  '域': 1005,
#  '夫': 1064,
#  '田': 2809,
#  '莱': 3675,
#  '六': 516,
#  '畜': 2824,
#  '车': 4227,
#  '辇': 4247,
#  '稽': 3084,
#  '比': 2295,
#  '吏': 785,
#  '诏': 4000,
#  '废': 1432,
#  '置': 3370,
#  '若': 3621,
#  '军': 540,
#  '旅': 1948,
#  '役': 1492,
#  '司': 771,
#  '马': 4773,
#  '众': 362,
#  '牛': 2680,
#  '卒': 689,
#  '伍': 357,
#  '皆': 2879,
#  '备': 1050,
#  '旗': 1956,
#  '兵': 522,
#  '器': 937,
#  '帅': 1375,
#  '凡': 568,
#  '造': 4329,
#  '邑': 4363,
#  '制': 607,
#  '韩': 4689,
#  '釜': 4436,
#  '山': 1305,
#  '士': 1042,
#  '卡': 697,
#  '尔': 1271,
#  '森': 2189,
#  '母': 2291,
#  '勤': 653,
#  '\u3000': 161,
#  '核': 2145,
#  '舰': 3553,
#  '抵': 1733,
#  '战': 1672,
#  '令': 344,
#  '基': 1008,
#  '朴': 2066,
#  '熙': 2649,
#  '摄': 1858,
#  '声': 1045,
#  '阻': 4575,
#  '止': 2265,
#  '友': 740,
#  '吸': 808,
#  '毒': 2293,
#  '告': 817,
#  '才': 1690,
#  '手': 1688,
#  '死': 2273,
#  '记': 3978,
#  '午': 683,
#  '获': 3678,
#  '悉': 1583,
#  '锋': 4498,
#  '故': 1902,
#  '伤': 369,
#  '害': 1231,
#  '罪': 3369,
#  '院': 4592,
#  '徒': 1506,
#  '刑': 592,
#  '常': 1393,
#  '菜': 3692,
#  '甑': 2799,
#  '某': 2118,
#  '淳': 2471,
#  '笪': 3149,
#  '抟': 1725,
#  '怠': 1548,
#  '樱': 2238,
#  '杆': 2073,
#  '昶': 1992,
#  '穑': 3087,
#  '盗': 2898,
#  '窃': 3096,
#  '拘': 1752,
#  '劳': 642,
#  '养': 527,
#  '玻': 2748,
#  '澳': 2561,
#  '辏': 4252,
#  '孩': 1198,
#  '贾': 4134,
#  '识': 3994,
#  '门': 4528,
#  '沟': 2353,
#  '租': 3064,
#  '蹦': 4217,
#  '痹': 2861,
#  '拢': 1758,
#  '眨': 2918,
#  '怀': 1537,
#  '男': 2814,
#  '续': 3298,
#  '联': 3427,
#  '吵': 807,
#  '辩': 4269,
#  '朋': 2050,
#  '架': 2114,
#  '轰': 4234,
#  '走': 4162,
#  '回': 946,
#  '躺': 4226,
#  '床': 1418,
#  '神': 3034,
#  '志': 1525,
#  '已': 1366,
#  '搏': 1850,
#  '往': 1495,
#  '医': 677,
#  '赶': 4165,
#  '得': 1508,
#  '知': 2957,
#  '危': 707,
#  '险': 4595,
#  '属': 1299,
#  '潜': 2551,
#  '逃': 4312,
#  '〖': 177,
#  '救': 1906,
#  '亡': 308,
#  '经': 3277,
#  '鉴': 4437,
#  '钝': 4454,
#  '致': 3533,
#  '脑': 3494,
#  '损': 1809,
#  '投': 1719,
#  '案': 2155,
#  '？': 4968,
#  '盲': 2906,
#  '足': 4173,
#  '疗': 2840,
#  '店': 1427,
#  '结': 3279,
#  '婚': 1155,
#  '妻': 1116,
#  '搬': 1854,
#  '指': 1777,
#  '控': 1830,
#  '但': 382,
#  '俩': 442,
#  '逅': 4314,
#  '否': 797,
#  '食': 4733,
#  '冰': 548,
#  '没': 2354,
#  '口': 752,
#  ...}

# %% [markdown]
# ### 使用朴素贝叶斯模型训练，并得到训练分数

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
#模型训练
model.fit(vectorizer.transform(x_train), y_train)
#使用训练好的模型进行预测
model.score(vectorizer.transform(x_test), y_test)
# Out:
# 0.9342666666666667

# %% [markdown]
# ### 将模型保存至本地文件

# %%
import pickle
file = open("model.pickle", "wb")
# 把模型写入到文件中
pickle.dump(model, file)
# 关闭文件
file.close()

# %% [markdown]
# ### 读取本地模型

# %%
file = open("model.pickle", "rb")
# 把模型从文件中读取出来
model = pickle.load(file)
# 关闭文件
file.close()

# %% [markdown]
# ### 使用本地模型预测

# %%
#test=["梁国杨氏子九岁，甚聪惠。孔君平诣其父，父不在，乃呼儿出。为设果，果有杨梅。孔指以示儿曰：“此是君家果。”儿应声答曰：“未闻孔雀是夫子家禽。”"]
for item in test:
    #print(item)
    item=" ".join(item)
    #print(item)
    test=[item]
test_result="classical"
test_data_pro=[]
for paragraph in test:
    test_data_pro.append(' '.join(list((re.sub("[\s+\.\!\/_,$%^*)(+\"\']+|[+——！，。？、~@#￥%……&*（）“”]", "",paragraph)))))
#print(test_data_pro)

ci_data_try=[]
train=[]
target=[]
cursor = c.execute("SELECT * from ci order by id desc limit 100")
for row in cursor:
    ci_data_try.append(row)

for i in range(0,len(ci_data_try)):
    train.append(ci_data_try[i][1])
    target.append(ci_data_try[i][2])

train_pro=[]
train_data_pro=[]
for paragraph in train:
    train_pro.append(' '.join(list((re.sub("[\s+\.\!\/_,$%^*)(+\"\']+|[+——！，。？、~@#￥%……&*（）]", "",paragraph)))))
#加start end 
for paragraph in train_pro:
    train_data_pro.append("<start> "+paragraph+" <end>")
    
print("预测值：", model.predict(vectorizer.transform(train)))
print("实际值：",target)

result=model.predict(vectorizer.transform(train))
count=0
for i in range(0,len(ci_data_try)):
    if(result[i]==target[i]):
        count=count+1
print("准确度为："+str(count/(len(ci_data_try))))

#result=model.predict(vectorizer.transform(test_data_pro))
#if(test_result==result[0]):
 #   print("预测成功！")
#if(test_result!=result[0]):
 #   print("预测失败了呢，再回去看看吧！")

# %%
file = open("model.pickle", "rb")
# 把模型从文件中读取出来
model = pickle.load(file)
# 关闭文件
file.close()

poetry_data_try=[]
train=[]
target=[]
cursor = c.execute("SELECT * from poet order by id desc limit 100")
for row in cursor:
    poetry_data_try.append(row)

for i in range(0,len(poetry_data_try)):
    train.append(poetry_data_try[i][1])
    target.append(poetry_data_try[i][2])
    
print("预测值：", model.predict(vectorizer.transform(train)))
print("实际值：",target)

result=model.predict(vectorizer.transform(train))
count=0
for i in range(0,len(poetry_data_try)):
    if(result[i]==target[i]):
        count=count+1
print("准确度为："+str(count/(len(poetry_data_try))))
# Out:
# 预测值： ['poet' 'poet' 'poet' 'poet' 'ci' 'poet' 'poet' 'ci' 'ci' 'ci' 'ci' 'ci'
#  'ci' 'ci' 'ci' 'ci' 'ci' 'ci' 'poet' 'ci' 'poet' 'ci' 'ci' 'poet' 'poet'
#  'ci' 'ci' 'poet' 'ci' 'ci' 'poet' 'poet' 'ci' 'ci' 'poet' 'poet' 'poet'
#  'ci' 'ci' 'ci' 'ci' 'poet' 'ci' 'poet' 'poet' 'ci' 'poet' 'poet' 'ci'
#  'ci' 'ci' 'ci' 'ci' 'ci' 'poet' 'poet' 'ci' 'poet' 'poet' 'ci' 'ci' 'ci'
#  'poet' 'poet' 'ci' 'poet' 'poet' 'ci' 'ci' 'ci' 'poet' 'poet' 'poet'
#  'poet' 'poet' 'poet' 'poet' 'ci' 'poet' 'poet' 'ci' 'poet' 'ci' 'ci'
#  'poet' 'poet' 'poet' 'poet' 'poet' 'poet' 'poet' 'ci' 'poet' 'poet'
#  'poet' 'poet' 'poet' 'poet' 'poet' 'poet']
# 实际值： ['poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet', 'poet']
# 准确度为：0.54

# %%
file = open("model.pickle", "rb")
# 把模型从文件中读取出来
model = pickle.load(file)
# 关闭文件
file.close()

modern_data_try=[]
train=[]
target=[]
cursor = c.execute("SELECT * from news order by id desc limit 50")
for row in cursor:
    modern_data_try.append(row)
cursor = c.execute("SELECT * from journal order by id desc limit 50")
for row in cursor:
    modern_data_try.append(row)
    
for i in range(0,len(modern_data_try)):
    train.append(modern_data_try[i][1])
    target.append(modern_data_try[i][2])
    
print("预测值：", model.predict(vectorizer.transform(train)))
print("实际值：",target)

result=model.predict(vectorizer.transform(train))
count=0
for i in range(0,len(modern_data_try)):
    if(result[i]==target[i]):
        count=count+1
print("准确度为："+str(count/(len(modern_data_try))))
# Out:
# 预测值： ['modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern' 'modern'
#  'modern' 'modern' 'modern' 'modern']
# 实际值： ['modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern']
# 准确度为：1.0

# %% [markdown]
# ## 2.2 TF-IDF向量作为特征

# %% [markdown]
# TF-IDF的分数代表了词语在文档和整个语料库中的相对重要性。TF-IDF分数由两部分组成：第一部分是计算标准的词语频率（TF），第二部分是逆文档频率（IDF）。其中计算语料库中文档总数除以含有该词语的文档数量，然后再取对数就是逆文档频率。
#
#
#
# TF(t)=（该词语在文档出现的次数）/（文档中词语的总数）
#
# IDF(t)= log_e（文档总数/出现该词语的文档总数）
#
# TF-IDF向量可以由不同级别的分词产生（单个词语，词性，多个词（n-grams））

# %% [markdown]
# #### （1）词语级tf-idf：矩阵代表了每个词语在不同文档中的TF-IDF分数

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#词语级tf-idf,使用tf-idf把文本转为向量
tfidf_vect = TfidfVectorizer(analyzer='char', max_features=5000, lowercase = False)
tfidf_vect.fit(x_train)
xtrain_tfidf = tfidf_vect.transform(x_train)
xtest_tfidf = tfidf_vect.transform(x_test)

#模型训练
classifier.fit(xtrain_tfidf, y_train)
#利用训练好的模型测试
classifier.score(xtest_tfidf, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-e193bdda3e79> in <module>
#       7
#       8 #模型训练
# ----> 9 classifier.fit(xtrain_tfidf, y_train)
#      10 #利用训练好的模型测试
#      11 classifier.score(xtest_tfidf, y_test)
#
# C:\ana\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     586         self : object
#     587         """
# --> 588         X, y = check_X_y(X, y, 'csr')
#     589         _, n_features = X.shape
#     590
#
# C:\ana\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     727         y = y.astype(np.float64)
#     728
# --> 729     check_consistent_length(X, y)
#     730
#     731     return X, y
#
# C:\ana\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [17500, 15000]

# %% [markdown]
# #### （2）ngram 级tf-idf：N-grams是多个词语在一起的组合，这个矩阵代表了N-grams的TF-IDF分数。

# %%
# ngram 级tf-idf
tfidf_vect_ngram = TfidfVectorizer(analyzer='char', ngram_range=(1,2), max_features=5000, lowercase = False)
tfidf_vect_ngram.fit(x_train)
xtrain_tfidf_ngram = tfidf_vect_ngram.transform(x_train)
xtest_tfidf_ngram = tfidf_vect_ngram.transform(x_test)

#模型训练
classifier.fit(xtrain_tfidf_ngram, y_train)
#利用训练好的模型测试
classifier.score(xtest_tfidf_ngram, y_test)
# Out:
# 0.9514913496721109

# %% [markdown]
# #### （3）词性级tf-idf：矩阵代表了语料中多个词性的TF-IDF分数

# %%
#词性级tf-idf
tfidf_vect_ngram_chars = TfidfVectorizer(analyzer='char', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram_chars.fit(x_train)
xtrain_tfidf_ngram_chars = tfidf_vect_ngram_chars.transform(x_train)
xtest_tfidf_ngram_chars = tfidf_vect_ngram_chars.transform(x_test)

#模型训练
classifier.fit(xtrain_tfidf_ngram_chars, y_train)
#利用训练好的模型测试
classifier.score(xtest_tfidf_ngram_chars, y_test)

# %% [markdown]
# # 3 构建模型

# %% [markdown]
# #### 之前一直都是用的朴素贝叶斯模型，那下面就换一个模型玩玩哈（没错就是线性回归模型）

# %%
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)

    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)

    if is_neural_net:
        predictions = predictions.argmax(axis=-1)

    return metrics.accuracy_score(predictions, y_test)

# %%
# Linear Classifier on Count Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_count, y_train, xtest_count)
print("LR, Count Vectors: ", accuracy)

#特征为词语级别TF-IDF向量的线性分类器
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf, y_train, xtest_tfidf)
print("LR, WordLevel TF-IDF: ", accuracy)

#特征为多个词语级别TF-IDF向量的线性分类器
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf_ngram, y_train, xtest_tfidf_ngram)
print("LR, N-Gram Vectors: ", accuracy)

#特征为词性级别TF-IDF向量的线性分类器
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf_ngram_chars, y_train, xtest_tfidf_ngram_chars)
print("LR, CharLevel Vectors: ", accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-46abf365c52f> in <module>
#       1 # Linear Classifier on Count Vectors
# ----> 2 accuracy = train_model(linear_model.LogisticRegression(), xtrain_count, y_train, xtest_count)
#       3 print("LR, Count Vectors: ", accuracy)
#       4
#       5 #特征为词语级别TF-IDF向量的线性分类器
#
# NameError: name 'linear_model' is not defined

# %% [markdown]
# #### 把朴素贝叶斯模型训练的结果一览呈现一下

# %%
#特征为计数向量的朴素贝叶斯
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_count, y_train, xtest_count)
print("NB, Count Vectors: ", accuracy)

#特征为词语级别TF-IDF向量的朴素贝叶斯
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, y_train, xtest_tfidf)
print("NB, WordLevel TF-IDF: ", accuracy)

#特征为多个词语级别TF-IDF向量的朴素贝叶斯
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram, y_train, xtest_tfidf_ngram)
print("NB, N-Gram Vectors: ", accuracy )

#特征为词性级别TF-IDF向量的朴素贝叶斯
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram_chars, y_train, xtest_tfidf_ngram_chars)
print("NB, CharLevel Vectors: ", accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-76c51acdfd7c> in <module>
#       1 #特征为计数向量的朴素贝叶斯
# ----> 2 accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_count, y_train, xtest_count)
#       3 print("NB, Count Vectors: ", accuracy)
#       4
#       5 #特征为词语级别TF-IDF向量的朴素贝叶斯
#
# NameError: name 'naive_bayes' is not defined

# %% [markdown]
# # 目前仍存在的问题

# %% [markdown]
# ## 1、没有用洗好的数据集以及加上start和end的分字训练，明天就训，今天电脑没电了
# ---
# 因为训练这么大的数据，会很花时间，所以可以在训练的时候干别的（不用电脑内存的）
# ## 2、没有加入验证集（选做）
# ## 3、还要加输入一段文本返回类别这个功能
